# %%
import  open3d as o3d
import numpy as np

# %%
pcd = o3d.io.read_point_cloud("/home/zzz2004/Downloads/LOAM/transformations.pcd")

# %%
pcd
# Out:
# PointCloud with 277 points.

# %%
pcd.rotate
# Out:
# <bound method PyCapsule.rotate of PointCloud with 277 points.>
